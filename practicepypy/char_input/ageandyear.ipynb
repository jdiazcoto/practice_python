# %% [markdown]
# # What should the program do?
# Create a program that asks the user to enter their name and their age. Print out a message addressed to them that tells them the year that they will turn 100 years old.
#
# Extras:
#
# 1. Add on to the previous program by asking the user for another number and printing out that many copies of the previous message. (Hint: order of operations exists in Python)
# 2. Print out that many copies of the previous message on separate lines. (Hint: the string "\n is the same as pressing the ENTER button)

# %%
name = input("What is your name? ")
age = input("What is your age? ")
year = input("What year are reading this? ")
# Out:
# What is your name?  J
# What is your age?  10
# What year are reading this?  2021

# %%
years_to_100 = 100 - int(age)

# %%
when_will_you_turn_100 = int(year) + years_to_100

# %%
for years in range(years_to_100):
    print("Esteemed " + name + " You will turn 100 in the year " + 
      str(when_will_you_turn_100) +"\n" )
# Out:
# Esteemed J You will turn 100 in the year 2111
#
# 0
# Esteemed J You will turn 100 in the year 2111
#
# 1
# Esteemed J You will turn 100 in the year 2111
#
# 2
# Esteemed J You will turn 100 in the year 2111
#
# 3
# Esteemed J You will turn 100 in the year 2111
#
# 4
# Esteemed J You will turn 100 in the year 2111
#
# 5
# Esteemed J You will turn 100 in the year 2111
#
# 6
# Esteemed J You will turn 100 in the year 2111
#
# 7
# Esteemed J You will turn 100 in the year 2111
#
# 8
# Esteemed J You will turn 100 in the year 2111
#
# 9
# Esteemed J You will turn 100 in the year 2111
#
# 10
# Esteemed J You will turn 100 in the year 2111
#
# 11
# Esteemed J You will turn 100 in the year 2111
#
# 12
# Esteemed J You will turn 100 in the year 2111
#
# 13
# Esteemed J You will turn 100 in the year 2111
#
# 14
# Esteemed J You will turn 100 in the year 2111
#
# 15
# Esteemed J You will turn 100 in the year 2111
#
# 16
# Esteemed J You will turn 100 in the year 2111
#
# 17
# ...
